# %%
from qiskit import QuantumCircuit
from qiskit_aer import AerSimulator
from qiskit.visualization import plot_histogram

# %%
qc = QuantumCircuit(4, 4)

# %%
qc.h(0)

# %%
qc.cx(0, 1)

# %%
qc.cx(1, 2)

# %%
qc.cx(2, 3)

# %%
qc.measure([0, 1, 2, 3], [0, 1, 2, 3])

# %%
print("Here is your 4-qubit Quantum Circuit:")
display(qc.draw("mpl"))
# Out:
# Here is your 4-qubit Quantum Circuit:

# %%
simulator = AerSimulator()
job = simulator.run(qc, shots=3000)
result = job.result()

# %%
counts = result.get_counts(qc)
print(f"Results after 3000 runs: {counts}")
display(plot_histogram(counts))
# Out:
# Results after 3000 runs: {'0000': 1518, '1111': 1482}
